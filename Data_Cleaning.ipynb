# %% [markdown]
# <a href="https://colab.research.google.com/github/tip0x/MachineLearning/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For this exercise, we will be needing pandas library only.

# %%
import pandas as pd

# %% [markdown]
# loading the dataset below

# %%
dst = pd.read_csv("/content/dst.csv")
dst.head()
# Out:
#     state      race                 candidate  gender is_incumbent party
# 0     Oyo  governor               Abba Adigun    Male          Yes    LP
# 1     Fct  governor           Abba Sidi Ahmed    Male           No   APM
# 2    Kogi  governor          Abdul Mayo Nyako    Male           No   YPP
# 3   Niger  governor                Abdul Sule    Male          Yes   ADP
# 4  Taraba  governor  Abdulganiyu Saka Olododo  Female           No    AA

# %% [markdown]
# How many unique values are there in the "party" column?

# %%
df = dst.party.unique()
df
# Out:
# array(['LP', 'APM', 'YPP', 'ADP', 'AA', 'NNPC', 'APGA', 'A', 'SDP', 'NRP',
#        'APC', 'NNPP', 'ZLP', 'AAC', 'Unknown', 'PDP', 'APP', 'NPM', 'ADC',
#        'NRM', 'ACD', 'BP', 'PRP', 'Independent', 'HIGH', 'TBD', 'LLC',
#        'ATM', 'NO', 'UNDO', 'YAPP'], dtype=object)

# %%
df_series = pd.Series(df)
df_series.shape[0]
# Out:
# 31

# %% [markdown]
# What is the count of rows that have "Yes" in the "is_incumbent" column?

# %%
dst['is_incumbent'].value_counts()
# Out:
# No     2874
# Yes     630
# Name: is_incumbent, dtype: int64

# %% [markdown]
# How many completely unique records are there in the datasets?

# %%
cand_list = dst['candidate'].value_counts()
cand_list.head(50)
# Out:
# Musa Idris Buko                    14
# Segun Adebayo                      13
# Ahmed Saba                         12
# Dare Bankole                       12
# Malam Yinka Aluko                  11
# Mukhtar Shagaya                    11
# Amb Wilfred Bonse                  11
# Bello Olatunde Emmanuel            11
# Umaru Aliyu Doma                   10
# Mohammed Omar Bio                  10
# Yakubu Adekunle                    10
# Sufiat Adekemi Iskil-Ogunyomi      10
# Victor Tamie Fingesi               10
# Ibrahim Ajia                        9
# Nentawe Yilwatda                    9
# Umar Larat Aliyu                    8
# Dr Olajide Abdulazeez Adeniran      8
# Anthony Ojesina                     8
# Sokunbi Kazeem                      8
# EngrSeyi Makinde                    8
# Dr Tofunmi Ogunronbi                8
# Engr Sunday Opoke                   8
# Agbomeji Olamide                    8
# Popoola Joshua                      8
# Hon Olutosin Emmanuel Jolaoluwa     8
# Isah Liman Kantigi                  8
# Joseph Ewuga                        8
# Mohammed Inyass                     8
# Mohammed Umar Bago                  8
# Falana Olufemi                      8
# Mr Adenipe Adekunle                 8
# Adebisi Oyewale                     8
# Yinusa Ayandoye                     8
# Adeshina Excel                      8
# Adeniran Oluwaseye                  8
# John James Akpan Udo-Edehe          7
# Muhammed Mansur Gada                7
# Kassim Jackie-Adunni                7
# Aliyu Sulaiman DanDauda             7
# Sani Dawop                          7
# Okunade Adeyemi                     7
# Caleb Mutfwang                      7
# Ekong Eyo Eyo                       7
# Prince Adedapo Abiodun              7
# Ekpo Ita Bassey                     7
# Alfred Dabwam                       7
# Agboyega Raymond                    7
# Adelanwa Kayemilola                 7
# Ibrahim Baba-inna                   7
# Enyinnaya Nwafor                    7
# Name: candidate, dtype: int64

# %%
cand_occurence = 'Bello Olatunde Emmanuel'
cand_counts = dst[dst['candidate'] == cand_occurence]
cand_counts
# Out:
#             state         race                candidate  gender is_incumbent  \
# 126        Rivers     governor  Bello Olatunde Emmanuel    Male           No
# 2745      Lagos  state house               Bashir Bashir    Male           No
# 2746      Lagos  state house               Bashir Bashir    Male           No
# 2755   Nasarawa  state house                   Beni Lard    Male          Yes
# 2756   Nasarawa  state house                   Beni Lard    Male          Yes
# 2788      Enugu  state house     Chinedum Enyinnaya Orji    Male           No
# 2789      Enugu  state house     Chinedum Enyinnaya Orji    Male           No
# 3274      Delta  state house            Okusanya Adedeji    Male           No
# 3275      Delta  state house            Okusanya Adedeji    Male           No
# 3276      Delta  state house            Okusanya Adedeji    Male           No
# 3277      Delta  state house            Okusanya Adedeji    Male           No
# 3278      Delta  state house            Okusanya Adedeji    Male           No
# 3279      Delta  state house            Okusanya Adedeji    Male           No
#
#      party
# 23     ADC
# 24     ADC
# 28     NRM
# 29     NRM
# 74      LP
# 75      LP
# 126   APGA
# 127   APGA
# 128   APGA
# 129   APGA
# 130   APGA
# 144    APP
# 145    APP
# 152     LP
# 153     LP
# 675   APGA
# 676   APGA
# 677   APGA
# 794     AA
# 795     AA
# 934   APGA
# 935   APGA
# 951    APC
# 952    APC
# 1520    BP
# 1521    BP
# 1522    BP
# 1523    BP
# 1814  APGA
# 1815  APGA
# 1816  APGA
# 2645   AAC
# 2646   AAC
# 2656   ACD
# 2657   ACD
# 2701   YPP
# 2702   YPP
# 2745   PDP
# 2746   PDP
# 2755    LP
# 2756    LP
# 2788   NRP
# 2789   NRP
# 3274    LP
# 3275    LP
# 3276    LP
# 3277    LP
# 3278    LP
# 3279    LP

# %%
no_dupd = dst.drop_duplicates(['state', 'race', 'candidate', 'gender', 'is_incumbent', 'party'], keep='first')
no_dupd
# Out:
#           state         race                 candidate  gender is_incumbent  \
# 0           Oyo     governor               Abba Adigun    Male          Yes
# 1           Fct     governor           Abba Sidi Ahmed    Male           No
# 2          Kogi     governor          Abdul Mayo Nyako    Male           No
# 3         Niger     governor                Abdul Sule    Male          Yes
# 4        Taraba     governor  Abdulganiyu Saka Olododo  Female           No
# ...         ...          ...                       ...     ...          ...
# 3499     Sokoto  state house           Yinusa Ayandoye    Male           No
# 3500      Lagos  state house         Yusuf Adamu Gagdi    Male          Yes
# 3501      Borno  state house             Yusuf Adebola    Male           No
# 3502      Niger  state house             Yusuf Adebola    Male           No
# 3503  Akwa ibom  state house              Zainab Gimba  Female          Yes
#
#      party
# 0       LP
# 1      APM
# 2      YPP
# 3      ADP
# 4       AA
# ...    ...
# 3499   ZLP
# 3500   APP
# 3501   APC
# 3502   NPM
# 3503   PRP
#
# [3474 rows x 6 columns]

# %%
no_dupd.shape[0]
# Out:
# 3474

# %%
dst.shape
# Out:
# (3504, 6)

# %%
cand_occurence = 'Bello Olatunde Emmanuel'
cand_counts = no_dupd[no_dupd['candidate'] == cand_occurence]
cand_counts
# Out:
#             state         race                candidate  gender is_incumbent  \
# 126        Rivers     governor  Bello Olatunde Emmanuel    Male           No
# 131         Gombe     governor  Bello Olatunde Emmanuel  Female           No
# 1009      Zamfara        house  Bello Olatunde Emmanuel  Female           No
# 1010      Bayelsa        house  Bello Olatunde Emmanuel  Female           No
# 1883         Yobe       senate  Bello Olatunde Emmanuel  Female           No
# 2751         Osun  state house  Bello Olatunde Emmanuel    Male           No
# 2752  Cross River  state house  Bello Olatunde Emmanuel  Female           No
#
#      party
# 126   APGA
# 131    YPP
# 1009     A
# 1010   SDP
# 1883   PRP
# 2751   PDP
# 2752   ZLP
